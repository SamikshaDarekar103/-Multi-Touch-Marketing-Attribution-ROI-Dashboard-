# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("cleaned_touchpoints.csv")
df.head()
# Out:
#                   event_time event_type  product_id          category_id  \
# 0  2019-10-01 01:32:09+00:00       view     2501614  2053013564003713919
# 1  2019-10-01 02:56:47+00:00       view     2501614  2053013564003713919
# 2  2019-10-01 03:05:49+00:00       view    26500447  2053013563550729061
# 3  2019-10-01 03:18:39+00:00       view    26203366  2053013563693335403
# 4  2019-10-01 03:20:58+00:00       view    26500136  2053013563550729061
#
#              category_code    brand   price    user_id  \
# 0  appliances.kitchen.oven  redmond  164.71  306441847
# 1  appliances.kitchen.oven  redmond  164.71  306441847
# 2                      NaN      NaN   26.77  362699320
# 3                      NaN      NaN  310.69  362699320
# 4                      NaN  lucente   91.38  362699320
#
#                            user_session
# 0  47641f8a-3aba-471a-8d07-014deccec567
# 1  47641f8a-3aba-471a-8d07-014deccec567
# 2  6c48ec39-b4be-4e62-a646-6c5d92de098c
# ...

# %%
print(df["user_id"].nunique())
# Out:
# 20384

# %%
print(df["user_session"].nunique())
# Out:
# 24382

# %%
df["event_type"].value_counts()
# Out:
# event_type
# view        97121
# purchase     1655
# cart         1207
# Name: count, dtype: int64

# %%
df["event_type"].value_counts().plot(kind="bar")
plt.show()

# %%
journey_length = df.groupby("user_session").size()
journey_length.describe()
# Out:
# count    24382.000000
# mean         4.100689
# std          5.535682
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          5.000000
# max        113.000000
# dtype: float64

# %%
journey_length.hist()
plt.show()
